# %% [markdown]
# <a href="https://colab.research.google.com/github/Olgynchik/-/blob/main/%D1%80%D0%B0%D0%B1%D0%BE%D1%82%D0%B0%20df%20%D0%B2%D1%82%D0%BE%D1%80%D0%BE%D0%B9%20%D1%81%D0%B5%D0%BC%D0%B8%D0%BD%D0%B0%D1%80%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Задание 1
# 1. скачать файл приложеный к материалу лекции
#
# 2. считать данные с помощью pandas
#
# 3. вывести на экран первые 5 строк
#
# 4. посмотреть на описание признаков и их содержание

# %%
import pandas as pd

df = pd.read_csv("/content/laptop_price .csv")# подгрузка и считывания данных с нужной таблицу
df.head()
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
# 3          4   Apple  MacBook Pro  Ultrabook    15.4
# 4          5   Apple  MacBook Pro  Ultrabook    13.3
#
#                      ScreenResolution                         Cpu   Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34kg
# ...

# %% [markdown]
# ## Задание 2
# Проведите первичный анализ данных
#
# 1. Изучите типы данных
# 2. Найдите количество пропущенных ячеек в данных
# 3. Посчитайте основные статистики по всем признакам и поизучайте их

# %%
df.info() # просмотр информации
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   laptop_ID         1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   Product           1303 non-null   object
#  3   TypeName          1303 non-null   object
#  4   Inches            1303 non-null   float64
#  5   ScreenResolution  1303 non-null   object
#  6   Cpu               1303 non-null   object
#  7   Ram               1303 non-null   object
#  8   Memory            1303 non-null   object
#  9   Gpu               1303 non-null   object
#  10  OpSys             1303 non-null   object
#  11  Weight            1303 non-null   object
#  12  Price_euros       1303 non-null   float64
# dtypes: float64(2), int64(1), object(10)
# memory usage: 132.5+ KB

# %%
df.isnull().sum() # просмотр есть ли пустые значения в таблице
# Out:
# laptop_ID           0
# Company             0
# Product             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price_euros         0
# dtype: int64

# %%
df.describe() # считает статистику по всем признакам
# Out:
#          laptop_ID       Inches  Price_euros
# count  1303.000000  1303.000000  1303.000000
# mean    660.155794    15.017191  1123.686992
# std     381.172104     1.426304   699.009043
# min       1.000000    10.100000   174.000000
# 25%     331.500000    14.000000   599.000000
# 50%     659.000000    15.600000   977.000000
# 75%     990.500000    15.600000  1487.880000
# max    1320.000000    18.400000  6099.000000

# %% [markdown]
# ## Задание 3.
# Ответьте на несколько вопросов
#
# 3.1 Ноутбуков от какой компании больше всего в наборе
# данных?
#
# 3.2 Какая минимальная и максимальная стоимость у
# ноутбуков в данных?
#
# 3.3 Найти  самый дорогой ноутбук и с какими характеристиками в данных?
#
# Выведите все характеристики только по этому ноутбуку
# Если таких ноутбуков несколько, то выводите их всех

# %%
df['Company'].value_counts() #3.1 поиск конкретных данный (фильтр) -> обращаемся  к нужному столбцу и указать функцию которая считает количество встречаемых значений в столбце
# Out:
# Dell         297
# Lenovo       297
# HP           274
# Asus         158
# Acer         103
# MSI           54
# Toshiba       48
# Apple         21
# Samsung        9
# Razer          7
# Mediacom       7
# Microsoft      6
# Xiaomi         4
# Vero           4
# Chuwi          3
# Google         3
# Fujitsu        3
# LG             3
# Huawei         2
# Name: Company, dtype: int64

# %%
df['Price_euros'].min(), df['Price_euros'].max()
# Out:
# (174.0, 6099.0)

# %%
df.sort_values("Price_euros", ascending=False).iloc[0] # сортируем  df от большего к меньшему по выбраному столбцу и выбираем всю строку по индексу
# Out:
# laptop_ID                                           200
# Company                                           Razer
# Product                                       Blade Pro
# TypeName                                         Gaming
# Inches                                             17.3
# ScreenResolution    4K Ultra HD / Touchscreen 3840x2160
# Cpu                         Intel Core i7 7820HK 2.9GHz
# Ram                                                32GB
# Memory                                          1TB SSD
# Gpu                             Nvidia GeForce GTX 1080
# OpSys                                        Windows 10
# Weight                                           3.49kg
# Price_euros                                      6099.0
# Name: 196, dtype: object

# %% [markdown]
# ## Задание 4.
# Ответьте на несколько вопросов
# 4.1 Найдите ноутбуки с самой маленькой диагональю в
# данных?
# Выведите только следующие характеристики:
# 1. Компания
# 2. Типа ноутбука
# 3. Диагональ
# 4. Стоимость
#
# Если таких ноутбуков несколько, то выводите их всех
#
# 4.2 Сколько стоит самый дорогой ноутбук у компании HP?
#
# 4.3 Как много ноутбуков Ultrabook с 8GB RAM?
#
# Найдите сколько таких ультрабуков с 8GB ОЗУ в процентном соотношении
# относительно всех ультрабуков

# %%
df[df['Inches'] == df['Inches'].min()] [['Company', 'TypeName', 'Inches', 'Price_euros']]# обращаемся ко всей таблице и в этой таблице обращаемся к нужному столбцу  и если этот столбец  == минимальному нужному показателю, и выводим нужные столбцы в виде списка
# Out:
#      Company            TypeName  Inches  Price_euros
# 50    Lenovo  2 in 1 Convertible    10.1       319.00
# 1082  Lenovo  2 in 1 Convertible    10.1       646.27
# 1114  Lenovo  2 in 1 Convertible    10.1       549.00
# 1126  Lenovo  2 in 1 Convertible    10.1       479.00

# %%
df[df['Company'] == 'HP']['Price_euros'].max() # 4.2
# Out:
# 4389.0

# %%
df.head()
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
# 3          4   Apple  MacBook Pro  Ultrabook    15.4
# 4          5   Apple  MacBook Pro  Ultrabook    13.3
#
#                      ScreenResolution                         Cpu   Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34kg
# ...

# %%
value1 = df[df['TypeName']=='Ultrabook'].shape[0]  # возвращает количество строк и столбцов в виде кортежа, если в квадратных скобках указать только одно значение то выведется количества то выведуться только кол -во строк
value2 = df[(df['TypeName']=='Ultrabook') & (df['Ram'] == '8GB')].shape[0] # количество ноутов с нужными значениями
value2/value1 # находим процентрое соотношение
# Out:
# 0.7142857142857143

# %% [markdown]
# ## Задание 5.
#
# 5.1 Выберите ноутбук клиенту
# Клиент хочет подобрать ноутбук с 8GB или 16GB ОЗУ на Windows 10 в
# стоимости до 500 евро, сколько у него вариантов?
#
# 5.2 Выберите ноутбук клиенту
# Клиент хочет подобрать ноутбук от MSI, с видеокартой Nvidia GeForce GTX
# 1050 Ti и главное не с диагональю 15.6. В какой ценовой категории вышли
# подобные ноутбуки?
#
# 5.3 Что дешевле?
# В среднем дешевле ноутбуки с CPU Intel Core i7 7700HQ 2.8GHz или с Intel
# Core i7 7600U 2.8GHz?

# %% [markdown]
# ### Пункт 5.1

# %%
df[((df['Ram']=='8GB') | (df['Ram'] == '16GB')) & (df['OpSys'] == 'Windows 10') & (df['Price_euros'] < 500)].shape[0]
# Out:
# 13

# %% [markdown]
# ### ПУНКТ 5.2

# %%
filter_data = df[(df['Company'] =='MSI') & (df['Gpu'] == 'Nvidia GeForce GTX 1050 Ti') & (df['Inches'] != 15.6)]
filter_data['Price_euros'].min(), filter_data['Price_euros'].max()
# Out:
# (1199.0, 1599.0)

# %% [markdown]
# ### ПУНКТ 5.3

# %%
first_cpu = df[df['Cpu'] == 'Intel Core i7 7700HQ 2.8GHz']['Price_euros'].mean()# средняя цена ноутов с определенным показателем
second_cpu = df[df['Cpu'] == 'Intel Core i7 7600U 2.8GHz']['Price_euros'].mean()
first_cpu, second_cpu
# Out:
# (1760.4084246575342, 1915.710769230769)

# %% [markdown]
# ## Задание 6
# Найдите самый легкий ноутбук
#
# Но обратите внимание на тип и представление данных в признаке Weight, если что, замените в строке 'kg' на пустую строку через метод .str.replace()

# %%
df['Weight'] = df['Weight'].str.replace('kg', '') # меняем в строковом типе данных кг на пустой символ
df['Weight'] # вывоим получившуюся таблицу

# %%
df['Weight'] = df['Weight'].astype('float')# меняем строковый тип данных на флот
df['Weight'].min()
# Out:
# 0.69
